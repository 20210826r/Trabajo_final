# %%
import pandas as pd
DF = pd.read_csv('tesis.csv')

# %%
DF['Año'] = pd.to_datetime(DF['Año'], format='%Y-%m-%d')
DF
# Out:
#                                            Institución  \
# 0    Pontificia Universidad Católica del Perú. Escu...
# 1    Pontificia Universidad Católica del Perú. Escu...
# 2    Pontificia Universidad Católica del Perú. Escu...
# 3    Pontificia Universidad Católica del Perú. Escu...
# 4    Pontificia Universidad Católica del Perú. Escu...
# ..                                                 ...
# 139  Universidad Nacional Agraria La Molina. Escuel...
# 140  Universidad Nacional Agraria La Molina. Escuel...
# 141  Universidad Nacional Agraria La Molina. Escuel...
# 142  Universidad Nacional Agraria La Molina. Escuel...
# 143  Universidad Nacional Agraria La Molina. Escuel...
#
#                                     Título de la tesis  \
# 0    Estimación del ciclo financiero utilizando mét...
# 1    Método para la fusión de categorías usando téc...
# 2    Redes neuronales convolucionales para datos co...
# 3    Modelo de regresión cuantílica para respuestas...
# 4    Clasiﬁcación de riesgo para frecuencias y seve...
# ..                                                 ...
# 139  Regresión bayesiana con enlaces asimétricos pa...
# 140  Estimación de componentes de varianza utilizan...
# 141  Modelos semiparamétricos de eventos recurrente...
# 142  Modelos estadísticos en procesos puntuales esp...
# 143  Aplicación de redes neuronales y regresión log...
#
#                       Nombre del tesista  \
# 0      Atoche Murrieta, Lilian Katherine
# 1              Farro Diaz, Victor Daniel
# 2      Cotacallapa Amanqui, Pavel Arturo
# 3          Manrique Urbina, Justo Andrés
# 4        Hernández Bello, Diana Patricia
# ..                                   ...
# 139  Fernández Vásquez, Richard Fernando
# 140          Vargas Paredes, Ana Cecilia
# 141    Rebaza Fernández, Diana del Rocío
# 142               Quispe Quispe, Braulio
# 143       Muñoz Muñoz, Emanuel Guillermo
#
#                                          Grado  \
# 0                      Magíster en Estadística
# 1                      Magíster en Estadística
# 2                      Magíster en Estadística
# 3                      Magíster en Estadística
# 4                      Magíster en Estadística
# ..                                         ...
# 139  Magister Scientiae - Estadística Aplicada
# 140  Magister Scientiae - Estadística Aplicada
# 141  Magister Scientiae - Estadística Aplicada
# 142  Magister Scientiae - Estadística Aplicada
# 143  Magister Scientiae - Estadística Aplicada
#
#                      Nombre del asesor  \
# 0                        Camiz, Sergio
# 1       Bayes Rodriguez, Cristian Luis
# 2        Benites Sanchez, Luis Enrique
# 3       Bayes Rodriguez, Cristian Luis
# 4      Valdivieso Serrano, Luis Hilmar
# ..                                 ...
# 139               Chue Gallardo, Jorge
# 140       Maehara Oyata, Víctor Manuel
# 141       Maehara Oyata, Víctor Manuel
# 142  López de Castilla Vásquez, Carlos
# 143               Chue Gallardo, Jorge
#
#                                                Resumen        Año
# 0    La presente tesis tiene por objetivo identific... 2022-09-22
# 1    En la actualidad, muchas organizaciones dispon... 2022-04-28
# 2    En muchas situaciones prácticas es necesario e... 2022-04-07
# 3    La presente tesis propone un modelo de regresi... 2022-03-21
# 4    En la tariﬁcación de seguros generales, en par... 2022-03-16
# ..                                                 ...        ...
# 139  En la actualidad las entidades bancarias convi... 2018-02-20
# 140  Se estimó mediante un modelo lineal mixto los ... 2017-11-13
# 141  La recurrencia de un evento en un paciente es ... 2017-11-13
# 142  La presente tesis plantea una aplicación de lo... 2017-10-03
# 143  El propósito de este trabajo es presentar y ap... 2016-08-02
#
# [144 rows x 7 columns]

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Institución         144 non-null    object
#  1   Título de la tesis  144 non-null    object
#  2   Nombre del tesista  144 non-null    object
#  3   Grado               144 non-null    object
#  4   Nombre del asesor   129 non-null    object
#  5   Resumen             144 non-null    object
#  6   Año                 144 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(6)
# memory usage: 8.0+ KB

# %%
filtered_DF = DF.query("Año >= '2020-01-01' \
                       and Año < '2020-12-31'")
filtered_DF
# Out:
#                                           Institución  \
# 21  Pontificia Universidad Católica del Perú. Escu...
# 22  Pontificia Universidad Católica del Perú. Escu...
# 23  Pontificia Universidad Católica del Perú. Escu...
# 24  Pontificia Universidad Católica del Perú. Escu...
# 25  Pontificia Universidad Católica del Perú. Escu...
#
#                                    Título de la tesis  \
# 21  Jointly modelling of cluster dependent pro les...
# 22  Regresión espacial cuantílica para variables a...
# 23  Extensión al modelo DINA reparametrizado con c...
# 24  Modelo bayesiano geoestadístico beta-inflacion...
# 25  Modelo lineal mixto de clases latentes con res...
#
#                       Nombre del tesista                    Grado  \
# 21        Cortés Tejada, Fernando Javier  Magíster en Estadística
# 22        García Céspedes, Carlos Jeffer  Magíster en Estadística
# 23         Sáenz Egúsquiza, Miguel Angel  Magíster en Estadística
# 24  Barriga Pozada, Alfonso Carlos Cesar  Magíster en Estadística
# 25       Renteria Sacha, Ivonne Mireille  Magíster en Estadística
#
#                   Nombre del asesor  \
# 21   Bayes Rodríguez, Cristian Luis
# 22      Quiroz Cornejo, Zaida Jesús
# 23  Valdivieso Serrano, Luis Hilmar
# 24      Quiroz Cornejo, Zaida Jesús
# 25  Valdivieso Serrano, Luis Hilmar
#
#                                               Resumen        Año
# 21  En la presente tesis se proponen modelos de cl... 2020-10-27
# 22  El Perú es un país emergente donde el desarrol... 2020-10-26
# 23  En el campo educacional, cuando los estudiante... 2020-10-20
# 24  En esta tesis proponemos un nuevo modelo geoes... 2020-09-29
# 25  Los modelos lineales mixtos de clases latentes... 2020-01-16

# %%
DF.describe()
# Out:
# C:\Users\KEMERLY\AppData\Local\Temp\ipykernel_17452\2918873499.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   DF.describe()
#                                               Institución  \
# count                                                 144
# unique                                                  4
# top     Universidad Nacional Agraria La Molina. Facult...
# freq                                                   63
# first                                                 NaN
# last                                                  NaN
#
#                                        Título de la tesis  \
# count                                                 144
# unique                                                144
# top     Estimación del ciclo financiero utilizando mét...
# freq                                                    1
# first                                                 NaN
# last                                                  NaN
#
#               Nombre del tesista                    Grado  \
# count                        144                      144
# unique                       142                        5
# top     Dongo Román, Andie Bryan  Magíster en Estadística
# freq                           2                       61
# first                        NaN                      NaN
# last                         NaN                      NaN
#
#                      Nombre del asesor  \
# count                              129
# unique                              32
# top     Bayes Rodríguez, Cristian Luis
# freq                                16
# first                              NaN
# last                               NaN
#
#                                                   Resumen                  Año
# count                                                 144                  144
# unique                                                144                  103
# top     La presente tesis tiene por objetivo identific...  2017-01-13 00:00:00
# freq                                                    1                    9
# first                                                 NaN  2012-08-15 00:00:00
# last                                                  NaN  2022-12-30 00:00:00

# %%
PUCP_P=DF.iloc[:61, :]
PUCP_P12 = len(PUCP_P.query("Año >= '2012-01-01' \
                       and Año < '2012-12-31'"))
PUCP_P13 = len(PUCP_P.query("Año >= '2013-01-01' \
                       and Año < '2013-12-31'"))
PUCP_P14 = len(PUCP_P.query("Año >= '2014-01-01' \
                       and Año < '2014-12-31'"))
PUCP_P15 = len(PUCP_P.query("Año >= '2015-01-01' \
                       and Año < '2015-12-31'"))
PUCP_P16 = len(PUCP_P.query("Año >= '2016-01-01' \
                       and Año < '2016-12-31'"))
PUCP_P17 = len(PUCP_P.query("Año >= '2017-01-01' \
                       and Año < '2017-12-31'"))
PUCP_P18 = len(PUCP_P.query("Año >= '2018-01-01' \
                       and Año < '2018-12-31'"))
PUCP_P19 = len(PUCP_P.query("Año >= '2019-01-01' \
                       and Año < '2019-12-31'"))
PUCP_P20 = len(PUCP_P.query("Año >= '2020-01-01' \
                       and Año < '2020-12-31'"))
PUCP_P21 = len(PUCP_P.query("Año >= '2021-01-01' \
                       and Año < '2021-12-31'"))
PUCP_P22 = len(PUCP_P.query("Año >= '2022-01-01' \
                       and Año < '2022-12-31'"))

PUCP_F = pd.DataFrame({'Institución': ['PUCP', 'PUCP', 'PUCP','PUCP', 'PUCP', 'PUCP', 'PUCP','PUCP','PUCP','PUCP','PUCP'],
                       'Año': [2012, 2013, 2014,2015, 2016, 2017, 2018,2019,2020,2021,2022],
                   'tesis por Año' : [PUCP_P12, PUCP_P13, PUCP_P14, 
                            PUCP_P15, PUCP_P16, PUCP_P17, 
                            PUCP_P18, PUCP_P19, PUCP_P20, 
                            PUCP_P21,PUCP_P22]})

PUCP_F
# Out:
#    Institución   Año  tesis por Año
# 0         PUCP  2012              4
# 1         PUCP  2013              4
# 2         PUCP  2014              0
# 3         PUCP  2015              6
# 4         PUCP  2016              6
# 5         PUCP  2017              4
# 6         PUCP  2018              6
# 7         PUCP  2019              5
# 8         PUCP  2020              5
# 9         PUCP  2021             14
# 10        PUCP  2022              7

# %%
UNALM_PRE=DF.iloc[61:124, :]
UNALM_PRE_P12 = len(UNALM_PRE.query("Año >= '2012-01-01' \
                       and Año < '2012-12-31'"))
UNALM_PRE_P13 = len(UNALM_PRE.query("Año >= '2013-01-01' \
                       and Año < '2013-12-31'"))
UNALM_PRE_P14 = len(UNALM_PRE.query("Año >= '2014-01-01' \
                       and Año < '2014-12-31'"))
UNALM_PRE_P15 = len(UNALM_PRE.query("Año >= '2015-01-01' \
                       and Año < '2015-12-31'"))
UNALM_PRE_P16 = len(UNALM_PRE.query("Año >= '2016-01-01' \
                       and Año < '2016-12-31'"))
UNALM_PRE_P17 = len(UNALM_PRE.query("Año >= '2017-01-01' \
                       and Año < '2017-12-31'"))
UNALM_PRE_P18 = len(UNALM_PRE.query("Año >= '2018-01-01' \
                       and Año < '2018-12-31'"))
UNALM_PRE_P19 = len(UNALM_PRE.query("Año >= '2019-01-01' \
                       and Año < '2019-12-31'"))
UNALM_PRE_P20 = len(UNALM_PRE.query("Año >= '2020-01-01' \
                       and Año < '2020-12-31'"))
UNALM_PRE_P21 = len(UNALM_PRE.query("Año >= '2021-01-01' \
                       and Año < '2021-12-31'"))
UNALM_PRE_P22 = len(UNALM_PRE.query("Año >= '2022-01-01' \
                       and Año < '2022-12-31'"))

UNALM_PREF = pd.DataFrame({'Institución': ['UNALM_PRE', 'UNALM_PRE', 'UNALM_PRE','UNALM_PRE', 'UNALM_PRE', 'UNALM_PRE', 'UNALM_PRE','UNALM_PRE','UNALM_PRE','UNALM_PRE','UNALM_PRE'],
                       'Año': [2012, 2013, 2014,2015, 2016, 2017, 2018,2019,2020,2021,2022],
                   'tesis por Año' : [UNALM_PRE_P12, UNALM_PRE_P13, UNALM_PRE_P14, 
                            UNALM_PRE_P15, UNALM_PRE_P16, UNALM_PRE_P17, 
                            UNALM_PRE_P18, UNALM_PRE_P19, UNALM_PRE_P20, 
                            UNALM_PRE_P21,UNALM_PRE_P22]})

UNALM_PREF
# Out:
#    Institución   Año  tesis por Año
# 0    UNALM_PRE  2012              0
# 1    UNALM_PRE  2013              0
# 2    UNALM_PRE  2014              0
# 3    UNALM_PRE  2015              0
# 4    UNALM_PRE  2016              2
# 5    UNALM_PRE  2017             13
# 6    UNALM_PRE  2018             13
# 7    UNALM_PRE  2019              4
# 8    UNALM_PRE  2020              0
# 9    UNALM_PRE  2021             24
# 10   UNALM_PRE  2022              7

# %%
UNALM_POST=DF.iloc[124:, :]
UNALM_POST_P12 = len(UNALM_POST.query("Año >= '2012-01-01' \
                       and Año < '2012-12-31'"))
UNALM_POST_P13 = len(UNALM_POST.query("Año >= '2013-01-01' \
                       and Año < '2013-12-31'"))
UNALM_POST_P14 = len(UNALM_POST.query("Año >= '2014-01-01' \
                       and Año < '2014-12-31'"))
UNALM_POST_P15 = len(UNALM_POST.query("Año >= '2015-01-01' \
                       and Año < '2015-12-31'"))
UNALM_POST_P16 = len(UNALM_POST.query("Año >= '2016-01-01' \
                       and Año < '2016-12-31'"))
UNALM_POST_P17 = len(UNALM_POST.query("Año >= '2017-01-01' \
                       and Año < '2017-12-31'"))
UNALM_POST_P18 = len(UNALM_POST.query("Año >= '2018-01-01' \
                       and Año < '2018-12-31'"))
UNALM_POST_P19 = len(UNALM_POST.query("Año >= '2019-01-01' \
                       and Año < '2019-12-31'"))
UNALM_POST_P20 = len(UNALM_POST.query("Año >= '2020-01-01' \
                       and Año < '2020-12-31'"))
UNALM_POST_P21 = len(UNALM_POST.query("Año >= '2021-01-01' \
                       and Año < '2021-12-31'"))
UNALM_POST_P22 = len(UNALM_POST.query("Año >= '2022-01-01' \
                       and Año < '2022-12-31'"))

UNALM_POSTF = pd.DataFrame({'Institución': ['UNALM_POST', 'UNALM_POST', 'UNALM_POST','UNALM_POST',
                                                'UNALM_POST', 'UNALM_POST', 'UNALM_POSTE','UNALM_POST','UNALM_POST',
                                                'UNALM_POST','UNALM_POST'],
                       'Año': [2012, 2013, 2014,2015, 2016, 2017, 2018,2019,2020,2021,2022],
                   'tesis por Año' : [UNALM_POST_P12, UNALM_POST_P13, UNALM_POST_P14, 
                            UNALM_POST_P15, UNALM_POST_P16, UNALM_POST_P17, 
                            UNALM_POST_P18, UNALM_POST_P19, UNALM_POST_P20, 
                            UNALM_POST_P21,UNALM_POST_P22]})

UNALM_POSTF
# Out:
#     Institución   Año  tesis por Año
# 0    UNALM_POST  2012              0
# 1    UNALM_POST  2013              0
# 2    UNALM_POST  2014              0
# 3    UNALM_POST  2015              0
# 4    UNALM_POST  2016              1
# 5    UNALM_POST  2017              3
# 6   UNALM_POSTE  2018              8
# 7    UNALM_POST  2019              6
# 8    UNALM_POST  2020              0
# 9    UNALM_POST  2021              1
# 10   UNALM_POST  2022              1

# %%
Numero_tesis = pd.concat([PUCP_F, UNALM_PREF,UNALM_POSTF])
Numero_tesis
# Out:
#     Institución   Año  tesis por Año
# 0          PUCP  2012              4
# 1          PUCP  2013              4
# 2          PUCP  2014              0
# 3          PUCP  2015              6
# 4          PUCP  2016              6
# 5          PUCP  2017              4
# 6          PUCP  2018              6
# 7          PUCP  2019              5
# 8          PUCP  2020              5
# 9          PUCP  2021             14
# 10         PUCP  2022              7
# 0     UNALM_PRE  2012              0
# 1     UNALM_PRE  2013              0
# 2     UNALM_PRE  2014              0
# 3     UNALM_PRE  2015              0
# 4     UNALM_PRE  2016              2
# 5     UNALM_PRE  2017             13
# 6     UNALM_PRE  2018             13
# 7     UNALM_PRE  2019              4
# 8     UNALM_PRE  2020              0
# 9     UNALM_PRE  2021             24
# 10    UNALM_PRE  2022              7
# 0    UNALM_POST  2012              0
# 1    UNALM_POST  2013              0
# 2    UNALM_POST  2014              0
# 3    UNALM_POST  2015              0
# 4    UNALM_POST  2016              1
# 5    UNALM_POST  2017              3
# 6   UNALM_POSTE  2018              8
# 7    UNALM_POST  2019              6
# 8    UNALM_POST  2020              0
# 9    UNALM_POST  2021              1
# 10   UNALM_POST  2022              1

# %%
TT_PUCP_P=len(DF.iloc[:61, :])
TT_UNALM_PRE=len(DF.iloc[61:124, :])
TT_UNALM_POST=len(DF.iloc[124:, :])
R_TESIS = pd.DataFrame({'Institución': ['PUCP_P', 'UNALM_PRE', 'UNALM_POST',],
                   'Numero_tesis_total' : [TT_PUCP_P, TT_UNALM_PRE, TT_UNALM_POST]})
R_TESIS
# Out:
#   Institución  Numero_tesis_total
# 0      PUCP_P                  61
# 1   UNALM_PRE                  63
# 2  UNALM_POST                  20

# %%
print(PUCP_P["Nombre del asesor"].value_counts())
len(PUCP_P["Nombre del asesor"].value_counts())
# Out:
# Bayes Rodríguez, Cristian Luis        16
# Valdivieso Serrano, Luis Hilmar       14
# Sal y Rosas Celi, Víctor Giancarlo     6
# Bazán Guzmán, Jorge Luis               6
# Quiroz Cornejo, Zaida Jesús            5
# Bayes Rodriguez, Cristian Luis         3
# Benites Sánchez, Luis Enrique          3
# Tarazona Vargas, Enver Gerald          3
# Doig Camino, Elizabeth                 2
# Camiz, Sergio                          1
# Benites Sanchez, Luis Enrique          1
# Sikov, Anna                            1
# Name: Nombre del asesor, dtype: int64
# 12

# %%
print(UNALM_PRE["Nombre del asesor"].value_counts())
len(UNALM_PRE["Nombre del asesor"].value_counts())
# Out:
# Menacho Chiok, César Higinio              8
# Rosas Villena, Fernando René              8
# Chue Gallardo, Jorge                      7
# Soto Rodríguez, Iván Dennys               6
# Salinas Flores, Jesús Walter              6
# Sotomayor Ruíz, Rino Nicanor              4
# Gamboa Unsihuay, Jesús Eduardo            2
# Miranda Villagómez, Clodomiro Fernando    1
# Valencia Chacón, Raphael Félix            1
# Vargas Paredes, Ana Cecilia               1
# Espinoza Villanueva, Luis Enrique         1
# Gonzáles Chavesta, Celso                  1
# López de Castilla Vásquez, Carlos         1
# Rubio Donet, Arturo                       1
# Name: Nombre del asesor, dtype: int64
# 14

# %%
print(UNALM_POST["Nombre del asesor"].value_counts())
len(UNALM_POST["Nombre del asesor"].value_counts())
# Out:
# Chue Gallardo, Jorge                      4
# Porras Cerrón, Jaime Carlos               3
# Miranda Villagomez, Clodomiro Fernando    3
# Maehara Oyata, Víctor Manuel              2
# Gamboa Unsihhuay, Jesús Eduardo           1
# Sotomayor Ruíz, Rino Nicanor              1
# Rosas Villena, Fernando René              1
# Febres Huamán, Grimaldo                   1
# Acevedo Mallque, Moisés Pascual           1
# Gonzáles Chavesta, Celso                  1
# Menacho Chiok, César Higinio              1
# López de Castilla Vásquez, Carlos         1
# Name: Nombre del asesor, dtype: int64
# 12
